# %% [markdown]
# <a href="https://colab.research.google.com/github/syedfiza7546/Data-Analysis-Projects-/blob/main/SF_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data1=pd.read_csv('/content/Salaries.csv')
# Out:
# <ipython-input-4-9bc0313fa97f>:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv('/content/Salaries.csv')

# %%
data1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data1[data1.isnull()].count()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               0
# Agency              0
# Status              0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data1=data1.drop(['Id','Notes','Agency','Status'],axis=1)

# %%
data1.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data1.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %%
data1['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
data1['JobTitle'].nunique()
# Out:
# 2159

# %%
data1[data1['JobTitle'].str.contains('captain',case=False)].shape[0]
# Out:
# 552

# %%
data1['BasePay'].str.count('0')
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 148649    3.0
# 148650    0.0
# 148651    0.0
# 148652    0.0
# 148653    3.0
# Name: BasePay, Length: 148654, dtype: float64

# %%
import numpy as np
data1['EmployeeName']=data1['EmployeeName'].replace('Not provided', np.nan)
data1[['BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year']]=data1[['BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year']].replace('Not Provided', np.nan)

# %%
data1
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay OvertimePay   OtherPay Benefits   TotalPay  \
# ...

# %%
data1.drop(data1[data1.isnull().sum(axis=1)==5].index,axis=0,inplace=True)

# %%
data1
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay OvertimePay   OtherPay Benefits   TotalPay  \
# ...

# %%
data1[data1['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# #**CONVERTING STR TO INT**

# %%
data1['BasePay'] = pd.to_numeric(data1['BasePay'], errors='coerce')
data1 = data1.dropna(subset=['BasePay'])
data1['BasePay'] = data1['BasePay'].astype(float)
data1
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#          BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# ...

# %%
data1[data1['BasePay'].max()==data1['BasePay']][['EmployeeName','BasePay']]
# Out:
#          EmployeeName   BasePay
# 72925  Gregory P Suhr  319275.0

# %%
data1.groupby('Year').mean('BasePay')
# Out:
#            BasePay      TotalPay  TotalPayBenefits
# Year
# 2011  63595.525872  71744.103871      71744.103871
# 2012  65435.992819  74113.262265     100553.229232
# 2013  69629.661009  78808.285041     102939.981346
# 2014  66564.085390  75471.836912     100261.438668

# %%
data1.groupby('JobTitle').mean('BasePay')
# Out:
#                                                      BasePay      TotalPay  \
# JobTitle
# ACCOUNT CLERK                                   43300.144578  44035.664337
# ACCOUNTANT                                      46643.000000  47429.268000
# ACCOUNTANT INTERN                               28732.229167  29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.000000  62290.780000
# ACUPUNCTURIST                                   66374.000000  67594.400000
# ...                                                      ...           ...
# X-RAY LABORATORY AIDE                           47664.230769  52705.880385
# X-Ray Laboratory Aide                           46085.970000  50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.000000  53632.870000
# Youth Comm Advisor                              39077.250000  41414.307500
# ZOO CURATOR                                     43148.000000  66686.560000
#
# ...

# %%
from matplotlib import pyplot as plt
_df_8['BasePay'].plot(kind='hist', bins=20, title='BasePay')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data1[data1['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.0

# %%
data1.groupby('JobTitle').count().sort_values(by='EmployeeName', ascending=False).head()
# Out:
#                               EmployeeName  BasePay  OvertimePay  OtherPay  \
# JobTitle
# Transit Operator                      6975     6975         6975      6975
# Special Nurse                         4382     4382         4382      4382
# Registered Nurse                      3725     3725         3725      3725
# Public Svc Aide-Public Works          2514     2514         2514      2514
# Police Officer 3                      2411     2411         2411      2411
#
#                               Benefits  TotalPay  TotalPayBenefits  Year
# JobTitle
# Transit Operator                  6975      6975              6975  6975
# Special Nurse                     4382      4382              4382  4382
# Registered Nurse                  3725      3725              3725  3725
# Public Svc Aide-Public Works      2514      2514              2514  2514
# Police Officer 3                  2411      2411              2411  2411

# %% [markdown]
# #**METHOD 2**

# %%
data1['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: count, dtype: int64
